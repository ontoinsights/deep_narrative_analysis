# %% [markdown]
# ## Initial list of idioms

# %%
import pickle
noun_dictionary = {"act of God": ":EnvironmentalOrEcologicalEvent",
                   "armed conflict": ":War",
                   "home": ":PhysicalLocation",  
                   "breaking and entering": ":RobberyAndTheft",
                   "charges": ":LegalEvent",
                   "cold shoulder": ":RefusalAndRejection",
                   "false step": ":Mistake",
                   "false papers": ":LegalInstrument",
                   "identification papers": ":LegalInstrument",
                   "helping hand": ":ProvisionOfAid",
                   "ill will": ":HatredBitternessAndDisgust",
                   "smoke screen": ":Concealment",
                   "thirst for knowledge": ":Curiosity",
                   "legal proceedings": ":LegalEvent",
                   "lack of judgment": ":Mistake",
                   "out of business": ":DissolutionOfBusiness",
                   "personal effects": ":Resource",
                   "position": ":Employment",
                   "post": ":Employment",
                   "peace of mind": ":RelaxationAndSerenity",
                   "school": ":Organization",
                   "strong-arm tactic": ":CoercionAndIntimidation",
                   "surprise attack": ":Battle",
                   "mutual assistance": ":Cooperation",
                   "word of honor": ":PromiseAndOath",
                   "crowd": ":GroupOfAgents",
                   "mob": ":GroupOfAgents"}
verb_dictionary = {"crack": "('joke' > :Joke) | (:AttackDamageAndAssault)",
                   "end": "('marriage' > :Divorce) | (:End)", 
                   "get": ":Possession", 
                   "give": "('back' & dobj > :ReturnRecoveryAndRelease ; :has_topic dobj) | " \
                           "('birth' > :Birth) | ('thanks' > :ExpressiveAndExclamation) | " \
                           "('way' > :SurrenderAndYielding) | ('word' > :PromiseAndOath) | (:GiftAndDonation)",
                   "hold": "('captive' & dobj > :CaptureAndSeizure ; :has_affected_agent dobj) | " \
                           "(dobj > :Storage ; :has_topic dobj)",
                   "keep": "('secret' & dobj > :Concealment ; :has_topic dobj) | " \
                           "(dobj > :Storage ; :has_topic dobj)",
                   "kill": "('self' > :Suicide) | (:MurderAndHomicide)",
                   "lack": "('judgment' > :Mistake) | (dobj > :Deficiency ; :has_topic dobj)", 
                   "lay":  "('bet' > :GamblingAndWagering) | (:InProcessPlacement)", 
                   "look": "('high and low' > :Searching) | ('the other way' > :IgnoringAndOverlooking) | " \
                           "(:SensoryPerception) ",
                   "make": "('appeal' > :RequestAndAppeal) | ('decision' > :DecisionMaking) | " \
                           "('known' & dobj > :Revelation ; :has_topic dobj) | ('mistake' > :Mistake) | " \
                           "(dobj > :ProductionManufactureAndCreation ; :has_topic dobj)",
                   "marry": "(dobj > :Marriage ; :has_active_agent dobj) | " \
                            "(pobj > :Marriage ; :has_active_agent pobj)",
                   "offer": "('thanks' > :ExpressiveAndExclamation) | (dobj > :GiftAndDonation ; :has_topic dobj)", 
                   "pay": "('no attention' > :IgnoringAndOverlooking) | ('no mind' > :IgnoringAndOverlooking) | " \
                          "(:PurchaseAndSale)",
                   "place": "('bet' > :GamblingAndWagering) | (:MovementTravelAndTransportation)", 
                   "put ": "('back together' & dobj > :Repair ; :has_topic dobj) | " \
                           "(:MovementTravelAndTransportation)",
                   "raise": "(Agent dobj > :CaringForDependents ; :has_affected_agent dobj) | " \
                            "(dobj > :Increase ; :has_topic dobj)",
                   "reach": "('resolution' > :Agreement) | ('verdict' > :LegalEvent) | " \
                            "(Location dobj > :MovementTravelAndTransportation ; :has_destination dobj) | " \
                            "(:EventAndState)",
                   "set": "('fire' > :Arson) | (dobj > :MovementTravelAndTransportation ; :has_topic dobj)",
                   "show": "('lack of judgment' > :Mistake) | (:Revelation)", 
                   "slip": "('away' > :EscapeAndEvasion) | (:BodyMovement)",
                   "take": "('back' & dobj > :Possession ; :has_topic dobj) | " \
                           "('control' > :Possession) | ('hostage' > :CaptivityAndDetention) | " \
                           "('leap in the dark' > :RiskTaking) | ('offensive' > :AttackDamageAndAssault) | " \
                           "('own life' > :Suicide) | ('trip' > :MovementTravelAndTransportation) | " \
                           "('vacation' > :MovementTravelAndTransportation) | " \
                           "('life' > :MurderAndHomicide) | (dobj > :Possession ; :has_topic dobj)",
                   "tell": "('joke' > :Joke) | (:CommunicationAndSpeechAct)",
                   "turn": "('blind eye' > :IgnoringAndOverlooking) | (:BodyMovement)", 
                   "wage": "('war' > :War) | (:ProjectAndCampaign)",
                   "wed": "(dobj > :Marriage ; :has_active_agent dobj) | " \
                          "(pobj > :Marriage ; :has_active_agent pobj)"}
verb_prep_dictionary = {"care for": "prep_for (Agent pobj > :CaringForDependent ; :has_affected_agent pobj) | " \
                                    "(pobj > :AttentionAndFocus ; :has_topic pobj)",
                        "care about": "prep_about (Agent pobj > :CompassionAndEmpathy ; :has_affected_agent pobj) | " \
                                      "(pobj > :AttentionAndFocus ; :has_topic pobj)",
                        "charge with": "prep_with (pobj > :LegalEvent ; :has_topic pobj)",
                        "give into": "prep_into (pobj > :Agreement ; :has_topic pobj)",
                        "go to": "prep_to ('battle' > :Battle) | (pobj > :MovementTravelAndTransportation)",
                        "go on": "prep_on ('strike' > :ProtestAndStrike) | " \
                                 "(pobj > :MovementTravelAndTransportation ; :has_instrument pobj)",
                        "hold in": "prep_in ('esteem' & dobj > :AdmirationAndRespect ; :has_affected_agent dobj) | " \
                                   "('regard' & dobj > :AdmirationAndRespect ; :has_affected_agent dobj) | " \
                                   "('reserve' & dobj > :Storage ; :has_topic dobj) | " \
                                   "(dobj & pobj > :Storage ; :has_topic dobj ; :has_instrument pobj)",
                        "look at": "prep_at (pobj > :AttentionAndFocus ; :has_topic pobj)",
                        "look for": "prep_for (pobj > :Searching ; :has_topic pobj)",
                        "put on": "prep_on (dobj > :Grooming ; :has_topic dobj)",
                        "return to": "prep_to (Location pobj > :MovementTravelAndTransportation ; :has_destination pobj) " \
                                     "| (pobj > :ReturnRecoveryAndRelease ; :has_topic pobj)",
                        "reunite with": "prep_with (Agent pobj > :InclusionAttachmentAndUnification ; :has_active_agent pobj) " \
                                        "| (pobj > :Possession ; :has_topic pobj)",
                        "take of": "prep_of ('possession' & pobj > :Possession ; :has_topic pobj)",
                        "take for": "prep_for ('responsibility' & pobj > :Acknowledgment ; :has_topic pobj)"}
verb_prt_dictionary = {"carry out": "dobj > :Ignore, dobj verb",
                       "cut down": "(Agent dobj > :MurderAndHomicide ; :has_affected_agent dobj) | " \
                                   "(dobj > :Decrease ; :has_topic dobj)",
                       "give back": ":ReturnRecoveryAndRelease",
                       "give up": ":SurrenderAndYielding",
                       "kick off": ":StartOrBeginning",
                       "put on": ":Grooming",
                       "round up": ":CaptureAndSeizure",
                       "shoot down": ":AttackDamageAndAssault",
                       "take over": "(Agent dobj > :InvasionAndOccupation ; :has_affected_agent dobj) | " \
                                    "(dobj > :InvasionAndOccupation ; :has_topic dobj)",
                       "touch up": ":Repair"}
verb_xcomp_dictionary = {"attempt": "xcomp > :Attempt, xcomp verb",
                         "carry": "xcomp > :Continuation, xcomp verb",
                         "continue": "xcomp > :Continuation, xcomp verb",
                         "give": "xcomp > :End, xcomp verb"}
with open('noun-idioms.pickle', 'wb') as outFile:
    pickle.dump(noun_dictionary, outFile)
with open('verb-idioms.pickle', 'wb') as outFile:
    pickle.dump(verb_dictionary, outFile)
with open('verb-prep-idioms.pickle', 'wb') as outFile:
    pickle.dump(verb_prep_dictionary, outFile)
with open('verb-prt-idioms.pickle', 'wb') as outFile:
    pickle.dump(verb_prt_dictionary, outFile)
with open('verb-xcomp-idioms.pickle', 'wb') as outFile:
    pickle.dump(verb_xcomp_dictionary, outFile)

# %%
from lark import Lark, Tree

with open('lark.txt', 'r') as inFile:
    lark_details = inFile.read()
dsl = Lark(lark_details)
rules = ["('joke' > :Joke) | (:AttackDamageAndAssault)",
         "('marriage' > :Divorce) | (:End)", 
         ":Possession", 
         "('back' & dobj > :ReturnRecoveryAndRelease ; :has_topic dobj) | " \
         "('birth' > :Birth) | ('thanks' > :ExpressiveAndExclamation) | " \
         "('way' > :SurrenderAndYielding) | ('word' > :PromiseAndOath) | (:GiftAndDonation)",
         "('captive' > :CaptureAndSeizure ; :has_affected_agent dobj) | " \
         "(dobj > :Storage ; :has_topic dobj)",
         "('secret' & dobj > :Concealment ; :has_topic dobj) | " \
         "(dobj > :Storage ; :has_topic dobj)",
         "('self' > :Suicide) | (:MurderAndHomicide)",
         "('judgment' > :Mistake) | (dobj > :Deficiency ; :has_topic dobj)", 
         "('bet' > :GamblingAndWagering) | (:InProcessPlacement)", 
         "('high and low' > :Searching) | ('the other way' > :IgnoringAndOverlooking) | " \
         "(:SensoryPerception) ",
         "('appeal' > :RequestAndAppeal) | ('decision' > :DecisionMaking) | " \
         "('known' & dobj > :Revelation ; :has_topic dobj) | ('mistake' > :Mistake) | " \
         "(dobj > :ProductionManufactureAndCreation ; :has_topic dobj)",
         "(dobj > :Marriage ; :has_active_agent dobj) | " \
         "(pobj > :Marriage ; :has_active_agent pobj)",
         "('thanks' > :ExpressiveAndExclamation) | (dobj > :GiftAndDonation ; :has_topic dobj)", 
         "('no attention' > :IgnoringAndOverlooking) | ('no mind' > :IgnoringAndOverlooking) | (:PurchaseAndSale)",
         "('bet' > :GamblingAndWagering) | (:MovementTravelAndTransportation)", 
         "('back together' & dobj > :Repair ; :has_topic dobj) | (:MovementTravelAndTransportation)",
         "(Agent dobj > :CaringForDependents ; :has_affected_agent dobj) | (dobj > :Increase ; :has_topic dobj)",
         "('resolution' > :Agreement) | ('verdict' > :LegalEvent) | " \
         "(Location dobj > :MovementTravelAndTransportation ; :has_destination dobj) | (:EventAndState)",
         "('fire' > :Arson) | (dobj > :MovementTravelAndTransportation ; :has_topic dobj)",
         "('lack of judgment' > :Mistake) | (:Revelation)", 
         "('away' > :EscapeAndEvasion) | (:BodyMovement)",
         "('back' & dobj > :Possession ; :has_topic dobj) | " \
         "('control' > :Possession) | ('hostage' > :CaptivityAndDetention) | " \
         "('leap in the dark' > :RiskTaking) | ('offensive' > :AttackDamageAndAssault) | " \
         "('own life' > :Suicide) | ('trip' > :MovementTravelAndTransportation) | " \
         "('vacation' > :MovementTravelAndTransportation) | " \
         "('life' > :MurderAndHomicide) | (dobj > :Possession ; :has_topic dobj)",
         "('joke' > :Joke) | (:CommunicationAndSpeechAct)",
         "('blind eye' > :IgnoringAndOverlooking) | (:BodyMovement)", 
         "('war' > :War) | (:ProjectAndCampaign)",
         "(dobj > :Marriage ; :has_active_agent dobj) | (pobj > :Marriage ; :has_active_agent pobj)",
         "prep_for (Agent pobj > :CaringForDependent ; :has_affected_agent pobj) | " \
         "(pobj > :AttentionAndFocus ; :has_topic pobj)",
         "prep_about (Agent pobj > :CompassionAndEmpathy ; :has_affected_agent pobj) | " \
         "(pobj > :AttentionAndFocus ; :has_topic pobj)",
         "prep_with (pobj > :LegalEvent ; :has_topic pobj)",
         "prep_into (pobj > :Agreement ; :has_topic pobj)",
         "prep_to ('battle' > :Battle) | (pobj > :MovementTravelAndTransportation)",
         "prep_on ('strike' > :ProtestAndStrike) | " \
         "(pobj > :MovementTravelAndTransportation ; :has_instrument pobj)",
         "prep_in ('esteem' & dobj > :AdmirationAndRespect ; :has_affected_agent dobj) | " \
         "('regard' & dobj > :AdmirationAndRespect ; :has_affected_agent dobj) | " \
         "('reserve' & dobj > :Storage ; :has_topic dobj) | " \
         "(dobj & pobj > :Storage ; :has_topic dobj ; :has_instrument pobj)",
         "prep_at (pobj > :AttentionAndFocus ; :has_topic pobj)",
         "prep_for (pobj > :Searching ; :has_topic pobj)",
         "prep_on (dobj > :Grooming ; :has_topic dobj)",
         "prep_to (Location pobj > :MovementTravelAndTransportation ; :has_destination pobj) " \
         "| (pobj > :ReturnRecoveryAndRelease ; :has_topic pobj)",
         "prep_with (Agent pobj > :InclusionAttachmentAndUnification ; :has_active_agent pobj) " \
         "| (pobj > :Possession ; :has_topic pobj)",
         "prep_of ('possession' & pobj > :Possession ; :has_topic pobj)",
         "prep_for ('responsibility' & pobj > :Acknowledgment ; :has_topic pobj)",
         "dobj > :Ignore, dobj verb",
         "(Agent dobj > :MurderAndHomicide ; :has_affected_agent dobj) | " \
         "(dobj > :Decrease ; :has_topic dobj)",
         "(Agent dobj > :InvasionAndOccupation ; :has_affected_agent dobj) | " \
         "(dobj > :InvasionAndOccupation ; :has_topic dobj)",
         "xcomp > :Attempt, xcompattack"]
         
for rule in rules:
    print(rule)
    rule_parse = dsl.parse(rule)
    print(rule_parse)
    print(rule_parse.pretty())
    print()
# Out:
# ('joke' > :Joke) | (:AttackDamageAndAssault)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'joke')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Joke')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'class_name'), [Token('WORD', 'AttackDamageAndAssault')])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           keyword_rule
#             text	joke
#             None
#             class_name	Joke
#       paren_rule
#         rule
#           class_name	AttackDamageAndAssault
#
#
# ('marriage' > :Divorce) | (:End)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'marriage')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Divorce')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'class_name'), [Token('WORD', 'End')])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           keyword_rule
#             text	marriage
#             None
#             class_name	Divorce
#       paren_rule
#         rule
#           class_name	End
#
#
# :Possession
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'class_name'), [Token('WORD', 'Possession')])])])
# start
#   rule
#     class_name	Possession
#
#
# ('back' & dobj > :ReturnRecoveryAndRelease ; :has_topic dobj) | ('birth' > :Birth) | ('thanks' > :ExpressiveAndExclamation) | ('way' > :SurrenderAndYielding) | ('word' > :PromiseAndOath) | (:GiftAndDonation)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'back')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), Tree(Token('RULE', 'class_name'), [Token('WORD', 'ReturnRecoveryAndRelease')]), Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'birth')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Birth')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'thanks')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'ExpressiveAndExclamation')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'way')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'SurrenderAndYielding')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'word')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'PromiseAndOath')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'class_name'), [Token('WORD', 'GiftAndDonation')])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           keyword_rule
#             text	back
#             object
#               dobj
#             class_name	ReturnRecoveryAndRelease
#             property_text
#               prop_name
#                 has
#                 topic
#               object
#                 dobj
#       paren_rule
#         rule
#           keyword_rule
#             text	birth
#             None
#             class_name	Birth
#       paren_rule
#         rule
#           keyword_rule
#             text	thanks
#             None
#             class_name	ExpressiveAndExclamation
#       paren_rule
#         rule
#           keyword_rule
#             text	way
#             None
#             class_name	SurrenderAndYielding
#       paren_rule
#         rule
#           keyword_rule
#             text	word
#             None
#             class_name	PromiseAndOath
#       paren_rule
#         rule
#           class_name	GiftAndDonation
#
#
# ('captive' > :CaptureAndSeizure ; :has_affected_agent dobj) | (dobj > :Storage ; :has_topic dobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'captive')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'CaptureAndSeizure')]), Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'affected'), Token('WORD', 'agent')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Storage')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           keyword_rule
#             text	captive
#             None
#             class_name	CaptureAndSeizure
#             property_text
#               prop_name
#                 has
#                 affected
#                 agent
#               object
#                 dobj
#       paren_rule
#         rule
#           obj_rule
#             None
#             object
#               dobj
#             None
#             class_name	Storage
#             property_or_verb
#               property_text
#                 prop_name
#                   has
#                   topic
#                 object
#                   dobj
#
#
# ('secret' & dobj > :Concealment ; :has_topic dobj) | (dobj > :Storage ; :has_topic dobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'secret')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), Tree(Token('RULE', 'class_name'), [Token('WORD', 'Concealment')]), Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Storage')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           keyword_rule
#             text	secret
#             object
#               dobj
#             class_name	Concealment
#             property_text
#               prop_name
#                 has
#                 topic
#               object
#                 dobj
#       paren_rule
#         rule
#           obj_rule
#             None
#             object
#               dobj
#             None
#             class_name	Storage
#             property_or_verb
#               property_text
#                 prop_name
#                   has
#                   topic
#                 object
#                   dobj
#
#
# ('self' > :Suicide) | (:MurderAndHomicide)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'self')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Suicide')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'class_name'), [Token('WORD', 'MurderAndHomicide')])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           keyword_rule
#             text	self
#             None
#             class_name	Suicide
#       paren_rule
#         rule
#           class_name	MurderAndHomicide
#
#
# ('judgment' > :Mistake) | (dobj > :Deficiency ; :has_topic dobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'judgment')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Mistake')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Deficiency')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           keyword_rule
#             text	judgment
#             None
#             class_name	Mistake
#       paren_rule
#         rule
#           obj_rule
#             None
#             object
#               dobj
#             None
#             class_name	Deficiency
#             property_or_verb
#               property_text
#                 prop_name
#                   has
#                   topic
#                 object
#                   dobj
#
#
# ('bet' > :GamblingAndWagering) | (:InProcessPlacement)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'bet')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'GamblingAndWagering')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'class_name'), [Token('WORD', 'InProcessPlacement')])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           keyword_rule
#             text	bet
#             None
#             class_name	GamblingAndWagering
#       paren_rule
#         rule
#           class_name	InProcessPlacement
#
#
# ('high and low' > :Searching) | ('the other way' > :IgnoringAndOverlooking) | (:SensoryPerception)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'high'), Token('WORD', 'and'), Token('WORD', 'low')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Searching')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'the'), Token('WORD', 'other'), Token('WORD', 'way')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'IgnoringAndOverlooking')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'class_name'), [Token('WORD', 'SensoryPerception')])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           keyword_rule
#             text
#               high
#               and
#               low
#             None
#             class_name	Searching
#       paren_rule
#         rule
#           keyword_rule
#             text
#               the
#               other
#               way
#             None
#             class_name	IgnoringAndOverlooking
#       paren_rule
#         rule
#           class_name	SensoryPerception
#
#
# ('appeal' > :RequestAndAppeal) | ('decision' > :DecisionMaking) | ('known' & dobj > :Revelation ; :has_topic dobj) | ('mistake' > :Mistake) | (dobj > :ProductionManufactureAndCreation ; :has_topic dobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'appeal')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'RequestAndAppeal')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'decision')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'DecisionMaking')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'known')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), Tree(Token('RULE', 'class_name'), [Token('WORD', 'Revelation')]), Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'mistake')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Mistake')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'ProductionManufactureAndCreation')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           keyword_rule
#             text	appeal
#             None
#             class_name	RequestAndAppeal
#       paren_rule
#         rule
#           keyword_rule
#             text	decision
#             None
#             class_name	DecisionMaking
#       paren_rule
#         rule
#           keyword_rule
#             text	known
#             object
#               dobj
#             class_name	Revelation
#             property_text
#               prop_name
#                 has
#                 topic
#               object
#                 dobj
#       paren_rule
#         rule
#           keyword_rule
#             text	mistake
#             None
#             class_name	Mistake
#       paren_rule
#         rule
#           obj_rule
#             None
#             object
#               dobj
#             None
#             class_name	ProductionManufactureAndCreation
#             property_or_verb
#               property_text
#                 prop_name
#                   has
#                   topic
#                 object
#                   dobj
#
#
# (dobj > :Marriage ; :has_active_agent dobj) | (pobj > :Marriage ; :has_active_agent pobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Marriage')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'active'), Token('WORD', 'agent')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Marriage')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'active'), Token('WORD', 'agent')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])])])])])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           obj_rule
#             None
#             object
#               dobj
#             None
#             class_name	Marriage
#             property_or_verb
#               property_text
#                 prop_name
#                   has
#                   active
#                   agent
#                 object
#                   dobj
#       paren_rule
#         rule
#           obj_rule
#             None
#             object
#               pobj
#             None
#             class_name	Marriage
#             property_or_verb
#               property_text
#                 prop_name
#                   has
#                   active
#                   agent
#                 object
#                   pobj
#
#
# ('thanks' > :ExpressiveAndExclamation) | (dobj > :GiftAndDonation ; :has_topic dobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'thanks')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'ExpressiveAndExclamation')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'GiftAndDonation')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           keyword_rule
#             text	thanks
#             None
#             class_name	ExpressiveAndExclamation
#       paren_rule
#         rule
#           obj_rule
#             None
#             object
#               dobj
#             None
#             class_name	GiftAndDonation
#             property_or_verb
#               property_text
#                 prop_name
#                   has
#                   topic
#                 object
#                   dobj
#
#
# ('no attention' > :IgnoringAndOverlooking) | ('no mind' > :IgnoringAndOverlooking) | (:PurchaseAndSale)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'no'), Token('WORD', 'attention')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'IgnoringAndOverlooking')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'no'), Token('WORD', 'mind')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'IgnoringAndOverlooking')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'class_name'), [Token('WORD', 'PurchaseAndSale')])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           keyword_rule
#             text
#               no
#               attention
#             None
#             class_name	IgnoringAndOverlooking
#       paren_rule
#         rule
#           keyword_rule
#             text
#               no
#               mind
#             None
#             class_name	IgnoringAndOverlooking
#       paren_rule
#         rule
#           class_name	PurchaseAndSale
#
#
# ('bet' > :GamblingAndWagering) | (:MovementTravelAndTransportation)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'bet')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'GamblingAndWagering')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'class_name'), [Token('WORD', 'MovementTravelAndTransportation')])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           keyword_rule
#             text	bet
#             None
#             class_name	GamblingAndWagering
#       paren_rule
#         rule
#           class_name	MovementTravelAndTransportation
#
#
# ('back together' & dobj > :Repair ; :has_topic dobj) | (:MovementTravelAndTransportation)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'back'), Token('WORD', 'together')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), Tree(Token('RULE', 'class_name'), [Token('WORD', 'Repair')]), Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'class_name'), [Token('WORD', 'MovementTravelAndTransportation')])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           keyword_rule
#             text
#               back
#               together
#             object
#               dobj
#             class_name	Repair
#             property_text
#               prop_name
#                 has
#                 topic
#               object
#                 dobj
#       paren_rule
#         rule
#           class_name	MovementTravelAndTransportation
#
#
# (Agent dobj > :CaringForDependents ; :has_affected_agent dobj) | (dobj > :Increase ; :has_topic dobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [Tree(Token('RULE', 'entity_type'), [Tree(Token('RULE', 'agent'), [])]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'CaringForDependents')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'affected'), Token('WORD', 'agent')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Increase')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           obj_rule
#             entity_type
#               agent
#             object
#               dobj
#             None
#             class_name	CaringForDependents
#             property_or_verb
#               property_text
#                 prop_name
#                   has
#                   affected
#                   agent
#                 object
#                   dobj
#       paren_rule
#         rule
#           obj_rule
#             None
#             object
#               dobj
#             None
#             class_name	Increase
#             property_or_verb
#               property_text
#                 prop_name
#                   has
#                   topic
#                 object
#                   dobj
#
#
# ('resolution' > :Agreement) | ('verdict' > :LegalEvent) | (Location dobj > :MovementTravelAndTransportation ; :has_destination dobj) | (:EventAndState)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'resolution')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Agreement')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'verdict')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'LegalEvent')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [Tree(Token('RULE', 'entity_type'), [Tree(Token('RULE', 'location'), [])]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'MovementTravelAndTransportation')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'destination')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'class_name'), [Token('WORD', 'EventAndState')])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           keyword_rule
#             text	resolution
#             None
#             class_name	Agreement
#       paren_rule
#         rule
#           keyword_rule
#             text	verdict
#             None
#             class_name	LegalEvent
#       paren_rule
#         rule
#           obj_rule
#             entity_type
#               location
#             object
#               dobj
#             None
#             class_name	MovementTravelAndTransportation
#             property_or_verb
#               property_text
#                 prop_name
#                   has
#                   destination
#                 object
#                   dobj
#       paren_rule
#         rule
#           class_name	EventAndState
#
#
# ('fire' > :Arson) | (dobj > :MovementTravelAndTransportation ; :has_topic dobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'fire')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Arson')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'MovementTravelAndTransportation')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           keyword_rule
#             text	fire
#             None
#             class_name	Arson
#       paren_rule
#         rule
#           obj_rule
#             None
#             object
#               dobj
#             None
#             class_name	MovementTravelAndTransportation
#             property_or_verb
#               property_text
#                 prop_name
#                   has
#                   topic
#                 object
#                   dobj
#
#
# ('lack of judgment' > :Mistake) | (:Revelation)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'lack'), Token('WORD', 'of'), Token('WORD', 'judgment')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Mistake')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'class_name'), [Token('WORD', 'Revelation')])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           keyword_rule
#             text
#               lack
#               of
#               judgment
#             None
#             class_name	Mistake
#       paren_rule
#         rule
#           class_name	Revelation
#
#
# ('away' > :EscapeAndEvasion) | (:BodyMovement)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'away')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'EscapeAndEvasion')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'class_name'), [Token('WORD', 'BodyMovement')])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           keyword_rule
#             text	away
#             None
#             class_name	EscapeAndEvasion
#       paren_rule
#         rule
#           class_name	BodyMovement
#
#
# ('back' & dobj > :Possession ; :has_topic dobj) | ('control' > :Possession) | ('hostage' > :CaptivityAndDetention) | ('leap in the dark' > :RiskTaking) | ('offensive' > :AttackDamageAndAssault) | ('own life' > :Suicide) | ('trip' > :MovementTravelAndTransportation) | ('vacation' > :MovementTravelAndTransportation) | ('life' > :MurderAndHomicide) | (dobj > :Possession ; :has_topic dobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'back')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), Tree(Token('RULE', 'class_name'), [Token('WORD', 'Possession')]), Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'control')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Possession')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'hostage')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'CaptivityAndDetention')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'leap'), Token('WORD', 'in'), Token('WORD', 'the'), Token('WORD', 'dark')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'RiskTaking')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'offensive')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'AttackDamageAndAssault')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'own'), Token('WORD', 'life')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Suicide')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'trip')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'MovementTravelAndTransportation')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'vacation')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'MovementTravelAndTransportation')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'life')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'MurderAndHomicide')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Possession')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           keyword_rule
#             text	back
#             object
#               dobj
#             class_name	Possession
#             property_text
#               prop_name
#                 has
#                 topic
#               object
#                 dobj
#       paren_rule
#         rule
#           keyword_rule
#             text	control
#             None
#             class_name	Possession
#       paren_rule
#         rule
#           keyword_rule
#             text	hostage
#             None
#             class_name	CaptivityAndDetention
#       paren_rule
#         rule
#           keyword_rule
#             text
#               leap
#               in
#               the
#               dark
#             None
#             class_name	RiskTaking
#       paren_rule
#         rule
#           keyword_rule
#             text	offensive
#             None
#             class_name	AttackDamageAndAssault
#       paren_rule
#         rule
#           keyword_rule
#             text
#               own
#               life
#             None
#             class_name	Suicide
#       paren_rule
#         rule
#           keyword_rule
#             text	trip
#             None
#             class_name	MovementTravelAndTransportation
#       paren_rule
#         rule
#           keyword_rule
#             text	vacation
#             None
#             class_name	MovementTravelAndTransportation
#       paren_rule
#         rule
#           keyword_rule
#             text	life
#             None
#             class_name	MurderAndHomicide
#       paren_rule
#         rule
#           obj_rule
#             None
#             object
#               dobj
#             None
#             class_name	Possession
#             property_or_verb
#               property_text
#                 prop_name
#                   has
#                   topic
#                 object
#                   dobj
#
#
# ('joke' > :Joke) | (:CommunicationAndSpeechAct)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'joke')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Joke')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'class_name'), [Token('WORD', 'CommunicationAndSpeechAct')])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           keyword_rule
#             text	joke
#             None
#             class_name	Joke
#       paren_rule
#         rule
#           class_name	CommunicationAndSpeechAct
#
#
# ('blind eye' > :IgnoringAndOverlooking) | (:BodyMovement)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'blind'), Token('WORD', 'eye')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'IgnoringAndOverlooking')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'class_name'), [Token('WORD', 'BodyMovement')])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           keyword_rule
#             text
#               blind
#               eye
#             None
#             class_name	IgnoringAndOverlooking
#       paren_rule
#         rule
#           class_name	BodyMovement
#
#
# ('war' > :War) | (:ProjectAndCampaign)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'war')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'War')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'class_name'), [Token('WORD', 'ProjectAndCampaign')])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           keyword_rule
#             text	war
#             None
#             class_name	War
#       paren_rule
#         rule
#           class_name	ProjectAndCampaign
#
#
# (dobj > :Marriage ; :has_active_agent dobj) | (pobj > :Marriage ; :has_active_agent pobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Marriage')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'active'), Token('WORD', 'agent')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Marriage')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'active'), Token('WORD', 'agent')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])])])])])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           obj_rule
#             None
#             object
#               dobj
#             None
#             class_name	Marriage
#             property_or_verb
#               property_text
#                 prop_name
#                   has
#                   active
#                   agent
#                 object
#                   dobj
#       paren_rule
#         rule
#           obj_rule
#             None
#             object
#               pobj
#             None
#             class_name	Marriage
#             property_or_verb
#               property_text
#                 prop_name
#                   has
#                   active
#                   agent
#                 object
#                   pobj
#
#
# prep_for (Agent pobj > :CaringForDependent ; :has_affected_agent pobj) | (pobj > :AttentionAndFocus ; :has_topic pobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'preposition_rule'), [Token('WORD', 'for'), Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [Tree(Token('RULE', 'entity_type'), [Tree(Token('RULE', 'agent'), [])]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'CaringForDependent')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'affected'), Token('WORD', 'agent')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])])])])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'AttentionAndFocus')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])])])])])])])])])])])
# start
#   rule
#     preposition_rule
#       for
#       complex_rule
#         paren_rule
#           rule
#             obj_rule
#               entity_type
#                 agent
#               object
#                 pobj
#               None
#               class_name	CaringForDependent
#               property_or_verb
#                 property_text
#                   prop_name
#                     has
#                     affected
#                     agent
#                   object
#                     pobj
#         paren_rule
#           rule
#             obj_rule
#               None
#               object
#                 pobj
#               None
#               class_name	AttentionAndFocus
#               property_or_verb
#                 property_text
#                   prop_name
#                     has
#                     topic
#                   object
#                     pobj
#
#
# prep_about (Agent pobj > :CompassionAndEmpathy ; :has_affected_agent pobj) | (pobj > :AttentionAndFocus ; :has_topic pobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'preposition_rule'), [Token('WORD', 'about'), Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [Tree(Token('RULE', 'entity_type'), [Tree(Token('RULE', 'agent'), [])]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'CompassionAndEmpathy')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'affected'), Token('WORD', 'agent')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])])])])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'AttentionAndFocus')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])])])])])])])])])])])
# start
#   rule
#     preposition_rule
#       about
#       complex_rule
#         paren_rule
#           rule
#             obj_rule
#               entity_type
#                 agent
#               object
#                 pobj
#               None
#               class_name	CompassionAndEmpathy
#               property_or_verb
#                 property_text
#                   prop_name
#                     has
#                     affected
#                     agent
#                   object
#                     pobj
#         paren_rule
#           rule
#             obj_rule
#               None
#               object
#                 pobj
#               None
#               class_name	AttentionAndFocus
#               property_or_verb
#                 property_text
#                   prop_name
#                     has
#                     topic
#                   object
#                     pobj
#
#
# prep_with (pobj > :LegalEvent ; :has_topic pobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'preposition_rule'), [Token('WORD', 'with'), Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'LegalEvent')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])])])])])])])])])])])
# start
#   rule
#     preposition_rule
#       with
#       complex_rule
#         paren_rule
#           rule
#             obj_rule
#               None
#               object
#                 pobj
#               None
#               class_name	LegalEvent
#               property_or_verb
#                 property_text
#                   prop_name
#                     has
#                     topic
#                   object
#                     pobj
#
#
# prep_into (pobj > :Agreement ; :has_topic pobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'preposition_rule'), [Token('WORD', 'into'), Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Agreement')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])])])])])])])])])])])
# start
#   rule
#     preposition_rule
#       into
#       complex_rule
#         paren_rule
#           rule
#             obj_rule
#               None
#               object
#                 pobj
#               None
#               class_name	Agreement
#               property_or_verb
#                 property_text
#                   prop_name
#                     has
#                     topic
#                   object
#                     pobj
#
#
# prep_to ('battle' > :Battle) | (pobj > :MovementTravelAndTransportation)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'preposition_rule'), [Token('WORD', 'to'), Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'battle')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Battle')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'MovementTravelAndTransportation')])])])])])])])])
# start
#   rule
#     preposition_rule
#       to
#       complex_rule
#         paren_rule
#           rule
#             keyword_rule
#               text	battle
#               None
#               class_name	Battle
#         paren_rule
#           rule
#             obj_rule
#               None
#               object
#                 pobj
#               None
#               class_name	MovementTravelAndTransportation
#
#
# prep_on ('strike' > :ProtestAndStrike) | (pobj > :MovementTravelAndTransportation ; :has_instrument pobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'preposition_rule'), [Token('WORD', 'on'), Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'strike')]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'ProtestAndStrike')])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'MovementTravelAndTransportation')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'instrument')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])])])])])])])])])])])
# start
#   rule
#     preposition_rule
#       on
#       complex_rule
#         paren_rule
#           rule
#             keyword_rule
#               text	strike
#               None
#               class_name	ProtestAndStrike
#         paren_rule
#           rule
#             obj_rule
#               None
#               object
# ...
#         paren_rule
#           rule
#             keyword_rule
#               text	reserve
#               object
#                 dobj
#               class_name	Storage
#               property_text
#                 prop_name
#                   has
#                   topic
#                 object
#                   dobj
#         paren_rule
#           rule
#             obj_rule
#               None
#               object
#                 dobj
#               object
#                 pobj
#               class_name	Storage
#               property_or_verb
#                 property_text
#                   prop_name
#                     has
#                     topic
#                   object
#                     dobj
#               property_or_verb
#                 property_text
#                   prop_name
#                     has
#                     instrument
#                   object
#                     pobj
#
#
# prep_at (pobj > :AttentionAndFocus ; :has_topic pobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'preposition_rule'), [Token('WORD', 'at'), Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'AttentionAndFocus')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])])])])])])])])])])])
# start
#   rule
#     preposition_rule
#       at
#       complex_rule
#         paren_rule
#           rule
#             obj_rule
#               None
#               object
#                 pobj
#               None
#               class_name	AttentionAndFocus
#               property_or_verb
#                 property_text
#                   prop_name
#                     has
#                     topic
#                   object
#                     pobj
#
#
# prep_for (pobj > :Searching ; :has_topic pobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'preposition_rule'), [Token('WORD', 'for'), Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Searching')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])])])])])])])])])])])
# start
#   rule
#     preposition_rule
#       for
#       complex_rule
#         paren_rule
#           rule
#             obj_rule
#               None
#               object
#                 pobj
#               None
#               class_name	Searching
#               property_or_verb
#                 property_text
#                   prop_name
#                     has
#                     topic
#                   object
#                     pobj
#
#
# prep_on (dobj > :Grooming ; :has_topic dobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'preposition_rule'), [Token('WORD', 'on'), Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Grooming')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])])])])])])])
# start
#   rule
#     preposition_rule
#       on
#       complex_rule
#         paren_rule
#           rule
#             obj_rule
#               None
#               object
#                 dobj
#               None
#               class_name	Grooming
#               property_or_verb
#                 property_text
#                   prop_name
#                     has
#                     topic
#                   object
#                     dobj
#
#
# prep_to (Location pobj > :MovementTravelAndTransportation ; :has_destination pobj) | (pobj > :ReturnRecoveryAndRelease ; :has_topic pobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'preposition_rule'), [Token('WORD', 'to'), Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [Tree(Token('RULE', 'entity_type'), [Tree(Token('RULE', 'location'), [])]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'MovementTravelAndTransportation')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'destination')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])])])])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'ReturnRecoveryAndRelease')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])])])])])])])])])])])
# start
#   rule
#     preposition_rule
#       to
#       complex_rule
#         paren_rule
#           rule
#             obj_rule
#               entity_type
#                 location
#               object
#                 pobj
#               None
#               class_name	MovementTravelAndTransportation
#               property_or_verb
#                 property_text
#                   prop_name
#                     has
#                     destination
#                   object
#                     pobj
#         paren_rule
#           rule
#             obj_rule
#               None
#               object
#                 pobj
#               None
#               class_name	ReturnRecoveryAndRelease
#               property_or_verb
#                 property_text
#                   prop_name
#                     has
#                     topic
#                   object
#                     pobj
#
#
# prep_with (Agent pobj > :InclusionAttachmentAndUnification ; :has_active_agent pobj) | (pobj > :Possession ; :has_topic pobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'preposition_rule'), [Token('WORD', 'with'), Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [Tree(Token('RULE', 'entity_type'), [Tree(Token('RULE', 'agent'), [])]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'InclusionAttachmentAndUnification')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'active'), Token('WORD', 'agent')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])])])])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Possession')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])])])])])])])])])])])
# start
#   rule
#     preposition_rule
#       with
#       complex_rule
#         paren_rule
#           rule
#             obj_rule
#               entity_type
#                 agent
#               object
#                 pobj
#               None
#               class_name	InclusionAttachmentAndUnification
#               property_or_verb
#                 property_text
#                   prop_name
#                     has
#                     active
#                     agent
#                   object
#                     pobj
#         paren_rule
#           rule
#             obj_rule
#               None
#               object
#                 pobj
#               None
#               class_name	Possession
#               property_or_verb
#                 property_text
#                   prop_name
#                     has
#                     topic
#                   object
#                     pobj
#
#
# prep_of ('possession' & pobj > :Possession ; :has_topic pobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'preposition_rule'), [Token('WORD', 'of'), Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'possession')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])]), Tree(Token('RULE', 'class_name'), [Token('WORD', 'Possession')]), Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])])])])])])])])])])
# start
#   rule
#     preposition_rule
#       of
#       complex_rule
#         paren_rule
#           rule
#             keyword_rule
#               text	possession
#               object
#                 pobj
#               class_name	Possession
#               property_text
#                 prop_name
#                   has
#                   topic
#                 object
#                   pobj
#
#
# prep_for ('responsibility' & pobj > :Acknowledgment ; :has_topic pobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'preposition_rule'), [Token('WORD', 'for'), Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'keyword_rule'), [Tree(Token('RULE', 'text'), [Token('WORD', 'responsibility')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])]), Tree(Token('RULE', 'class_name'), [Token('WORD', 'Acknowledgment')]), Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])])])])])])])])])])
# start
#   rule
#     preposition_rule
#       for
#       complex_rule
#         paren_rule
#           rule
#             keyword_rule
#               text	responsibility
#               object
#                 pobj
#               class_name	Acknowledgment
#               property_text
#                 prop_name
#                   has
#                   topic
#                 object
#                   pobj
#
#
# dobj > :Ignore, dobj verb
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Ignore')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'other_verb'), [Tree(Token('RULE', 'dobj'), []), Tree(Token('RULE', 'text'), [Token('WORD', 'verb')])])])])])])
# start
#   rule
#     obj_rule
#       None
#       object
#         dobj
#       None
#       class_name	Ignore
#       property_or_verb
#         other_verb
#           dobj
#           text	verb
#
#
# (Agent dobj > :MurderAndHomicide ; :has_affected_agent dobj) | (dobj > :Decrease ; :has_topic dobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [Tree(Token('RULE', 'entity_type'), [Tree(Token('RULE', 'agent'), [])]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'MurderAndHomicide')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'affected'), Token('WORD', 'agent')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'Decrease')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           obj_rule
#             entity_type
#               agent
#             object
#               dobj
#             None
#             class_name	MurderAndHomicide
#             property_or_verb
#               property_text
#                 prop_name
#                   has
#                   affected
#                   agent
#                 object
#                   dobj
#       paren_rule
#         rule
#           obj_rule
#             None
#             object
#               dobj
#             None
#             class_name	Decrease
#             property_or_verb
#               property_text
#                 prop_name
#                   has
#                   topic
#                 object
#                   dobj
#
#
# (Agent dobj > :InvasionAndOccupation ; :has_affected_agent dobj) | (dobj > :InvasionAndOccupation ; :has_topic dobj)
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [Tree(Token('RULE', 'entity_type'), [Tree(Token('RULE', 'agent'), [])]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'InvasionAndOccupation')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'affected'), Token('WORD', 'agent')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])])]), Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [None, Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'InvasionAndOccupation')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])])])])])])])])
# start
#   rule
#     complex_rule
#       paren_rule
#         rule
#           obj_rule
#             entity_type
#               agent
#             object
#               dobj
#             None
#             class_name	InvasionAndOccupation
#             property_or_verb
#               property_text
#                 prop_name
#                   has
#                   affected
#                   agent
#                 object
#                   dobj
#       paren_rule
#         rule
#           obj_rule
#             None
#             object
#               dobj
#             None
#             class_name	InvasionAndOccupation
#             property_or_verb
#               property_text
#                 prop_name
#                   has
#                   topic
#                 object
#                   dobj
#
#
# xcomp > :Attempt, xcompattack
# Tree(Token('RULE', 'start'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'xcomp_rule'), [Tree(Token('RULE', 'class_name'), [Token('WORD', 'Attempt')]), Tree(Token('RULE', 'other_verb'), [Tree(Token('RULE', 'xcomp'), []), Tree(Token('RULE', 'text'), [Token('WORD', 'attack')])])])])])
# start
#   rule
#     xcomp_rule
#       class_name	Attempt
#       other_verb
#         xcomp
#         text	attack

# %%
rule = ":Possession"
print('class_name', rule)
rule_parse = dsl.parse(rule)
tree = rule_parse.children[0].children[0]
class_name = tree.children[0].value
print(class_name)
print()

rule = "xcomp > :Attempt, xcomp attack"
print('xcomp', rule)
rule_parse = dsl.parse(rule)
tree = rule_parse.children[0].children[0]
class_tree, verb_tree = tree.children
print(class_tree.children[0].value)
xcomp, text = verb_tree.children
print(text.children[0].value)
print()

rule = "'back' & dobj > :ReturnRecoveryAndRelease ; :has_topic dobj"
print('keyword', rule)
rule_parse = dsl.parse(rule)
tree = rule_parse.children[0].children[0]        
if len(tree.children) == 4:
    text_tree, objects_tree, class_tree, property_tree = tree.children
else:
    text_tree, objects_tree, class_tree = tree.children
    property_tree = None
looking_for = ''
for text in text_tree.children:
    looking_for += f'{text.value} '
print(looking_for[:-1])
if objects_tree:
    print(objects_tree.children[0].data)
print(class_tree.children[0].value)
if property_tree:
    print(property_tree)
    prop_names, prop_obj_type = property_tree.children
    prop_name = ':'
    for pname in prop_names.children:
        prop_name += f'{pname.value}_'
    print(prop_name[:-1])
    print(prop_obj_type.children[0].data)
print()
    
rule = "prep_for (Agent pobj > :CaringForDependent ; :has_affected_agent pobj)"
print('preposition', rule)
rule_parse = dsl.parse(rule)
tree = rule_parse.children[0].children[0] 
prep_tree, complex_rule = tree.children
print(prep_tree.value)
print(complex_rule)
print()

rule = "Agent dobj > :CaringForDependents ; :has_affected_agent dobj"
# rule = "dobj > :Ignore, dobj verb"
rule = "dobj & pobj > :Storage ; :has_topic dobj ; :has_instrument pobj"
print('object', rule)
rule_parse = dsl.parse(rule)
tree = rule_parse.children[0].children[0] 
entity_tree = tree.children[0]
obj1_tree = tree.children[1]
obj2_tree = tree.children[2]
class_tree = tree.children[3]
prop_or_verbs = []
if len(tree.children) > 4:
    for i in range(4, len(tree.children)):
        prop_or_verbs.append(tree.children[i]) 
if entity_tree:
    print(entity_tree.children[0].data)
print(obj1_tree.children[0].data)
if obj2_tree:
    print(obj2_tree.children[0].data)
print(class_tree.children[0].value)
for prop_or_verb in prop_or_verbs:
    if prop_or_verb.children[0].data == 'property_text':   
        prop_names, prop_obj_type = prop_or_verb.children[0].children
        prop_name = ':'
        for pname in prop_names.children:
            prop_name += f'{pname.value}_'
        print(prop_name[:-1])
        print(prop_obj_type.children[0].data)
    else:
        obj_type, text = prop_or_verb.children[0].children
        print(obj_type.data)
        print(text.children[0].value)
# Out:
# class_name :Possession
# Possession
#
# xcomp xcomp > :Attempt, xcomp attack
# Attempt
# attack
#
# keyword 'back' & dobj > :ReturnRecoveryAndRelease ; :has_topic dobj
# back
# dobj
# ReturnRecoveryAndRelease
# Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'topic')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'dobj'), [])])])
# :has_topic
# dobj
#
# preposition prep_for (Agent pobj > :CaringForDependent ; :has_affected_agent pobj)
# for
# Tree(Token('RULE', 'complex_rule'), [Tree(Token('RULE', 'paren_rule'), [Tree(Token('RULE', 'rule'), [Tree(Token('RULE', 'obj_rule'), [Tree(Token('RULE', 'entity_type'), [Tree(Token('RULE', 'agent'), [])]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])]), None, Tree(Token('RULE', 'class_name'), [Token('WORD', 'CaringForDependent')]), Tree(Token('RULE', 'property_or_verb'), [Tree(Token('RULE', 'property_text'), [Tree(Token('RULE', 'prop_name'), [Token('WORD', 'has'), Token('WORD', 'affected'), Token('WORD', 'agent')]), Tree(Token('RULE', 'object'), [Tree(Token('RULE', 'pobj'), [])])])])])])])])
#
# object dobj & pobj > :Storage ; :has_topic dobj ; :has_instrument pobj
# dobj
# pobj
# Storage
# :has_topic
# dobj
# :has_instrument
# pobj
