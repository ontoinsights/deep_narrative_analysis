# %% [markdown]
# ## Initial list of idioms

# %%
import pickle
verb_dictionary = {"add to": "pobj > :Increase & :has_topic pobj", 
                   "ask for": "pobj > :Inquiry & :RequestAndAppeal & :has_topic pobj",
                   "belong to": "subj & Agent pobj > :Affiliation & :affiliated_agent subj & :affiliated_with pobj",
                   "belong to": "subj & non-Agent pobj > :Possession & :has_topic subj & :has_agent pobj",
                   "charge with": "pobj > :LegalEvent & :has_topic pobj",
                   "close": "Organization subj > :DissolutionOfOrganization & :has_topic subj",
                   "close": "Organization dobj > :DissolutionOfOrganization & :has_topic dobj",
                   "cut down": "Plant dobj > :RemovalOfRawMaterials & :has_topic dobj",
                   "cut down": "non-Plant dobj > :Decrease & :has_topic dobj",
                   "fish around": ":Searching",
                   "filled with": "dobj & Resource pobj > :InProcessPlacement & :has_topic dobj & :has_instrument pobj",
                   "filled with": "non-Resource pobj > ignore",
                   "root around": ":Searching",
                   "get back": ":ReturnRecoveryAndRelease",
                   "give back": ":ReturnRecoveryAndRelease", 
                   "take back": ":ReturnRecoveryAndRelease", 
                   "get hold of": "pobj > :Possession & :has_topic pobj", 
                   "get married": ":Marriage",
                   "give birth": ":Birth",
                   "give thanks": ":ExpressiveAndExclamation", 
                   "offer thanks": ":ExpressiveAndExclamation", 
                   "get rid of": "pobj > :RemovalAndRestriction & :has_topic pobj",
                   "get tired of": "pobj > :AngerAndAnnoyance & :has_topic pobj",
                   "go out of business": ":DissolutionOfOrganization",
                   "give in": ":SurrenderAndYielding",
                   "give way": ":SurrenderAndYielding",
                   "take control of": "pobj > :CaptureAndSeizure & :has_topic pobj",
                   "care for": "Agent pobj > :CaringForDependent & :has_affected_agent pobj",
                   "care about": "Agent pobj > :CompassionAndEmpathy & :has_affected_agent pobj",
                   "care for": "non-Agent pobj > :AttentionAndFocus & :has_topic pobj",
                   "care about": "non-Agent pobj > :AttentionAndFocus & :has_topic pobj",
                   "carry out": "dobj > verb",
                   "carry on": "+xcomp > :Continuation & verb",
                   "knock off": ":MurderAndHomicide",
                   "go to battle": ":Battle",
                   "hold ... in esteem": "Agent dobj > :AdmirationAndRespect & :has_affected_agent dobj",
                   "hold ... in regard": "Agent dobj > :AdmirationAndRespect & :has_affected_agent dobj",
                   "hold ... in reserve": "Resource dobj > :Storage & :has_topic dobj",
                   "kick off": "dobj > :StartOrBeginning & verb",
                   "pour out": "Emotion dobj > verb",
                   "lay open": ":Revelation",
                   "long for": "pobj > :LongingAndPassion & :has_topic pobj",
                   "look for": "pobj > :Searching & :has_topic pobj",
                   "make known": ":Revelation",
                   "touch up": "dobj > :Repair & :has_topic dobj",
                   "seek to": "+xcomp > :Attempt & verb",
                   "strive to": "+xcomp > :Attempt & verb",
                   "set aside": "dobj > :Separation & :has_topic dobj",
                   "set apart": "dobj > :Separation & :has_topic dobj",
                   "shoot down": "physical dobj > :AttackDamageAndAssault & :has_topic dobj",
                   "shoot down": "non-physical dobj > :RefusalAndRejection & :has_topic dobj",
                   "slip away": ":EscapeAndEvasion",
                   "take over": "Agent dobj > :InvasionAndOccupation & :has_affected_agent dobj",
                   "take over": "non-Agent dobj > :InvasionAndOccupation & :has_topic dobj",
                   "take possession of": "physical pobj > :Possession & :has_topic pobj", 
                   "take responsibility for": "pobj > :Acknowledgment & :has_topic pobj",
                   "put in view": ":Revelation",
                   "wage war": ":War",
                   "walk out": ":MovementTravelAndTransportation & :AngerAndAnnoyance"}
noun_override_dictionary = {"act of God": ":EnvironmentalOrEcologicalEvent",
                            "armed conflict": ":War",
                            "breaking and entering": ":RobberyAndTheft",
                            "cold shoulder": ":RefusalAndRejection",
                            "false step": ":Mistake",
                            "fond memories": ":Nostalgia",
                            "guidance": ":AdviceAndRecommendation",
                            "head in the sand": ":IgnoringAndOverlooking",
                            "helping hand": ":ProvisionOfAid",
                            "ill will": ":HatredBitternessAndDisgust",
                            "smoke screen": ":Concealment",
                            "thirst for knowledge": ":Curiosity",
                            "legal proceedings": ":LegalEvent",
                            "lack of judgment": ":Mistake",
                            "personal effects": ":Possession",
                            "position": ":Employment",
                            "post": ":Employment",
                            "peace of mind": ":RelaxationAndSerenity",
                            "risk": ":RiskTaking", 
                            "strong-arm tactic": ":CoercionAndIntimidation",
                            "surprise attack": ":Battle",
                            "mutual assistance": ":Cooperation",
                            "word of honor": ":PromiseAndOath",
                            "captive": "Agent dobj > :CaptureAndSeizure & :has_affected_agent dobj",
                            "no go": "subj > :Impossibility :has_topic subj",
                            "Zionist": "subj > :has_political_ideology :enum:Nationalism & :political ideology 'Zionism'"}
verb_noun_dictionary = {"end, marriage": ":Divorce",
                        "look high and low": ":Searching",
                        "look the other way": ":IgnoringAndOverlooking",
                        "pay no attention": ":IgnoringAndOverlooking", 
                        "pay no mind": ":IgnoringAndOverlooking", 
                        "turn blind eye": ":IgnoringAndOverlooking", 
                        "get, hands on": "physical pobj > :Possession & :has_topic pobj", 
                        "get, divorce": ":Divorce",
                        "give, word": ":PromiseAndOath",
                        "kill, self": ":Suicide",
                        "take, own life": ":Suicide",
                        "take, life": "default :MurderAndHomicide",
                        "reach resolution": ":Agreement",
                        "lack judgment": ":Mistake", 
                        "show, lack of judgment": ":Mistake", 
                        "place, bet": ":GamblingAndWagering", 
                        "lay, bet":  ":GamblingAndWagering", 
                        "play the horses": ":GamblingAndWagering",
                        "make, mistake": ":Mistake",
                        "make, decision": ":DecisionMaking",
                        "make, appeal": ":RequestAndAppeal",
                        "crack, joke": ":Joke",
                        "tell, joke": ":Joke",
                        "raise, children": "dobj > :CaringForDependents & :has_affected_agent dobj",
                        "go on strike": ":ProtestAndStrike",
                        "set fire": ":Arson",
                        "take the offensive": ":AttackDamageAndAssault",
                        "stick, neck out": ":RiskTaking", 
                        "take, leap in the dark": ":RiskTaking", 
                        "put on, clothes": ":Grooming",
                        "put, back together": "physical dobj > :Repair & :has_topic dobj",
                        "take, hostage": "Agent dobj > :Abduction & :has_affected_agent dobj",
                        "take, trip": ":MovementTravelAndTransportation",
                        "take, vacation": ":MovementTravelAndTransportation",
                        "keep, secret": "dobj > :Concealment & :has_topic dobj"}
with open('verb-idioms.pickle', 'wb') as outFile:
    pickle.dump(verb_dictionary, outFile)
with open('noun-idioms.pickle', 'wb') as outFile:
    pickle.dump(noun_override_dictionary, outFile)
with open('verb-noun-idioms.pickle', 'wb') as outFile:
    pickle.dump(verb_noun_dictionary, outFile)
