# %% [markdown]
# ## Initial list of idioms

# %%
import pickle
verb_dictionary = {"belong to": "prep_to (Agent pobj > :Affiliation ; :affiliated_with obj_uri) | " \
                                " (pobj > :Possession ; :has_topic subj_uri ; :has_agent obj_uri)",
                   "charge with": "prep_with (pobj > :LegalEvent ; :has_topic obj_uri)",
                   "cut down": "(Plant dobj > :RemovalOfRawMaterials ; :has_topic obj_uri) | (Agent dobj > :MurderAndHomicide ; :has_affected_agent obj_uri) | " \
                               "(dobj > :Decrease ; :has_topic obj_uri)",
                   "fish around": ":Searching",
                   "filled with": "prep_with (Resource pobj & dobj > :InProcessPlacement ; :has_topic dobj ; :has_instrument pobj)",
                   "root around": ":Searching",
                   "get 'back'": "(dobj > :ReturnRecoveryAndRelease, :Possession ; :has_topic obj_uri) | (default > :ReturnRecoveryAndRelease)", 
                   "give 'back'": "dobj > :ReturnRecoveryAndRelease ; :has_topic obj_uri", 
                   "take 'back'": "(dobj > :ReturnRecoveryAndRelease, :Possession ; :has_topic obj_uri) | (default > :ReturnRecoveryAndRelease)", 
                   "get 'tired'": "prep_of (pobj > :AngerAndAnnoyance ; :has_topic obj_uri)",
                   "give up": ":SurrenderAndYielding",
                   "give into": "prep_into (pobj > :Agreement ; :has_topic obj_uri)",
                   "care for": "prep_for (Agent pobj > :CaringForDependent ; :has_affected_agent obj_uri) | (pobj > :AttentionAndFocus ; :has_topic obj_uri)",
                   "care about": "prep_about (Agent pobj > :CompassionAndEmpathy ; :has_affected_agent obj_uri) | (pobj > :AttentionAndFocus ; :has_topic obj_uri)",
                   "carry out": "dobj > dobj verb",
                   "carry on": "+xcomp > :Continuation, xcomp verb",
                   "knock off": "(Person dobj > :MurderAndHomicide ; :has_affected_agent obj_uri) | (dobj > :End ; :has_topic obj_uri)",
                   "go to": "prep_to ('battle' > :Battle) | (pobj > :MovementTravelAndTransportation ; :has_destination obj_uri)",
                   "go on strike": "prep_on ('strike' > :ProtestAndStrike) | (pobj > :MovementTravelAndTransportation ; :has_instrument obj_uri)",
                   "hold in": "prep_in (Agent dobj & 'esteem' pobj > :AdmirationAndRespect ; :has_affected_agent obj_uri) | " \
                                      "(Agent dobj & 'regard' pobj > :AdmirationAndRespect ; :has_affected_agent obj_uri) | " \
                                      "(dobj > :Storage ; :has_topic obj_uri)",
                   "kick off": "(Agent dobj > :Death ; :has_affected_agent obj_uri) | (dobj > :StartOrBeginning, dobj verb)",
                   "pour out": "(EmotionalResponse dobj > dobj verb) | (dobj > :InProcessPlacement ; :has_topic obj_uri)",
                   "lay open": ":Revelation",
                   "look for": "pobj > :Searching ; :has_topic obj_uri",
                   "marry": "(dobj > :Marriage ; :has_active_agent obj_uri) | (Person pobj > :Marriage ; :has_active_agent obj_uri) | " \
                            "(pobj > :Acknowledgement, :PositiveEmotion ; :has_topic obj_uri)",
                   "wed": "(dobj > :Marriage ; :has_active_agent obj_uri) | (Person pobj > :Marriage ; :has_active_agent obj_uri) | " \
                          "(pobj > :Acknowledgement, :PositiveEmotion ; :has_topic obj_uri)",
                   "put on": "(Resource dobj > :Grooming)",
                   "raise": "(Agent dobj > :CaringForDependents ; :has_affected_agent obj_uri) | (dobj > :Increase ; :has_topic obj_uri)",
                   "reunite with": "prep_with (Person pobj > :InclusionAttachmentAndUnification ; :has_affected_agent obj_uri) | (pobj > :Possession ; :has_topic obj_uri)",
                   "round up": ":CaptureAndSeizure",
                   "touch up": "dobj > :Repair ; :has_topic obj_uri",
                   "seek to": "+xcomp > :Attempt, xcomp verb",
                   "stick out": "('neck' > :RiskTaking) | (dobj > :Continuation ; :has_topic obj_uri)", 
                   "strive to": "+xcomp > :Attempt, xcomp verb",
                   "set 'aside'": "dobj > :Separation ; :has_topic obj_uri",
                   "set 'apart'": "dobj > :Separation ; :has_topic obj_uri",
                   "shoot down": "(Resource dobj > :AttackDamageAndAssault ; :has_topic obj_uri) | (dobj > :RefusalAndRejection ; :has_topic obj_uri)",
                   "slip 'away'": ":EscapeAndEvasion",
                   "take over": "(Agent dobj > :InvasionAndOccupation ; :has_affected_agent obj_uri} | (dobj > :InvasionAndOccupation ; :has_topic obj_uri)",
                   "put 'back together'": "Resource dobj > :Repair ; :has_topic obj_uri"}
noun_override_dictionary = {"act of God": ":EnvironmentalOrEcologicalEvent",
                            "armed conflict": ":War",
                            "officer": "('army' > inst_uri a :Person . inst_uriArmyAffiliation a :Affiliation ; :affiliated_agent inst_uri ; :affiliated_with :ArmedForce) | " \
                                       "('police' > inst_uri a :Person . inst_uriPoliceAffiliation a :Affiliation ; :affiliated_agent inst_uri ; :affiliated_with :PoliceForce) | " \
                                       "(:Person)",
                            "breaking and entering": ":RobberyAndTheft",
                            "charges": ":LegalEvent",
                            "cold shoulder": ":RefusalAndRejection",
                            "false step": ":Mistake",
                            "false papers": ":LegalInstrument",
                            "identification papers": ":LegalInstrument",
                            "fond memories": ":Nostalgia",
                            "head in the sand": ":IgnoringAndOverlooking",
                            "helping hand": ":ProvisionOfAid",
                            "ill will": ":HatredBitternessAndDisgust",
                            "smoke screen": ":Concealment",
                            "thirst for knowledge": ":Curiosity",
                            "legal proceedings": ":LegalEvent",
                            "lack of judgment": ":Mistake",
                            "out of business": ":DissolutionOfBusiness",
                            "personal effects": ":Resource",
                            "position": ":Employment",
                            "post": ":Employment",
                            "peace of mind": ":RelaxationAndSerenity",
                            "school": ":Organization",
                            "strong-arm tactic": ":CoercionAndIntimidation",
                            "surprise attack": ":Battle",
                            "mutual assistance": ":Cooperation",
                            "word of honor": ":PromiseAndOath",
                            "mob": ":GroupOfAgents",
                            "captive": "Agent dobj > event_uri a :CaptureAndSeizure ; :has_affected_agent obj_uri"}
verb_noun_dictionary = {"end 'marriage'": ":Divorce", 
                        "give 'birth'": ":Birth", 
                        "look 'high and low'": ":Searching",
                        "look 'the other way'": ":IgnoringAndOverlooking",
                        "pay 'no attention'": ":IgnoringAndOverlooking", 
                        "pay 'no mind'": ":IgnoringAndOverlooking", 
                        "turn 'blind eye'": ":IgnoringAndOverlooking", 
                        "get 'hands on'": "prep_on pobj > :Possession ; :has_topic obj_uri", 
                        "get 'hold of'": "prep_of pobj > :Possession ; :has_topic obj_uri", 
                        "give 'word'": ":PromiseAndOath",
                        "give 'way'": ":SurrenderAndYielding",
                        "give 'thanks'": ":ExpressiveAndExclamation", 
                        "offer 'thanks'": ":ExpressiveAndExclamation", 
                        "kill 'self'": ":Suicide",
                        "take 'life'": "('own' > :Suicide) | (default > :MurderAndHomicide)",
                        "reach 'resolution'": ":Agreement",
                        "lack 'judgment'": ":Mistake", 
                        "make 'known'": "dobj > :Revelation ; :has_topic obj_uri",
                        "take 'possession of'": "pobj > :Possession ; :has_topic obj_uri", 
                        "take 'responsibility for'": "pobj > :Acknowledgment ; :has_topic obj_uri",
                        "show 'lack of judgment'": ":Mistake", 
                        "place 'bet'": ":GamblingAndWagering", 
                        "lay 'bet'":  ":GamblingAndWagering", 
                        "play 'horses'": ":GamblingAndWagering",
                        "make 'mistake'": ":Mistake",
                        "make 'decision'": ":DecisionMaking",
                        "make 'appeal'": ":RequestAndAppeal",
                        "take 'control'": ":Possession, :Command",
                        "crack 'joke'": ":Joke",
                        "tell 'joke'": ":Joke",
                        "set 'fire'": ":Arson",
                        "take 'offensive'": ":AttackDamageAndAssault",
                        "take 'leap in the dark'": ":RiskTaking",
                        "take 'hostage'": "Agent dobj > :Abduction ; :has_affected_agent obj_uri",
                        "take 'trip'": ":MovementTravelAndTransportation",
                        "take 'vacation'": ":MovementTravelAndTransportation",
                        "keep 'secret'": "dobj > :Concealment ; :has_topic obj_uri",
                        "wage 'war'": ":War"}
with open('verb-idioms.pickle', 'wb') as outFile:
    pickle.dump(verb_dictionary, outFile)
with open('noun-idioms.pickle', 'wb') as outFile:
    pickle.dump(noun_override_dictionary, outFile)
with open('verb-noun-idioms.pickle', 'wb') as outFile:
    pickle.dump(verb_noun_dictionary, outFile)
